# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruviprj700-jpg/ai.portfolio/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
students = pd.DataFrame({
    "students":["John", "Mary", "Ali", "Grace",
                "James", "Faith", "Brian", "Lucy"],
    "Age":[20,21,22,20,23,21,22,20],
    "Gender":["Male", "Female", "Male", "Male",
              "Male", "Female", "Male", "Female"],
    "Math":[78,85,90,66,74,88,82,91],
    "Science":[80,79,95,70,88,90,76,90],
    "English":[75,88,92,72,81,86,79,90]
})

# %%
print(students)
# Out:
#   students  Age  Gender  Math  Science  English
# 0     John   20    Male    78       80       75
# 1     Mary   21  Female    85       79       88
# 2      Ali   22    Male    90       95       92
# 3    Grace   20    Male    66       70       72
# 4    James   23    Male    74       88       81
# 5    Faith   21  Female    88       90       86
# 6    Brian   22    Male    82       76       79
# 7     Lucy   20  Female    91       90       90

# %%
#A line chart shows trends over time or ordered data.
plt.plot(students["students"], students["Math"])
plt.show()

# %%
#Adding titles
plt.plot(students["students"], students["Math"])
plt.title("Math Scores")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(students, Marks)
plt.title("Students Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_671/1887841508.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(students, Marks)
#       4 plt.title("Students Marks")
#       5 plt.xlabel("Students")
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
# ...

# %% [markdown]
# Bar Chart

# %% [markdown]
# display English marks using horizontal bar chart

# %%
import matplotlib.pyplot as plt
plt.barh(students,["Student", students["English"]])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(range(len(Marks)), Marks)
plt.xlabel("Student Index")
plt.ylabel("Marks")
plt.title("Student Marks Scatter Plot")
plt.show()

# %%
plt.hist(students["Math"])
plt.show

# %%
#Changing the number of bins
plt.hist(students["Math"], bins=5)
plt.show()

# %%
gender_counts = students["Gender"].value_counts()
plt.pie(gender_counts)
plt.show()

# %%
import pandas as pd
import matplobtlib.pylot as plt

learners =pd.DataFrame({
    "Name":["Mark","Mitchell","Collins","Philip","Samuel","Lucy"],
    "Maths":[78,65,88,72,91,60],
    "Science":[82,70,90,68,87,64],
    "English":[75,80,85,70,92,68]
})

print(learners.head())

learners.plot(x="Name", y="Maths",kind="line")
plt.show()
learners.plot(x="Name", y="Science",kind="line")
plt.show()
learners.plot(x="Name", y="English",kind="line")
plt.show()

# %% [markdown]
# seaborn
# seaborn is a python library built on top of matplotlib. it creates beatiful graphics with very little code

# %%
import seaborn as sns

# %%
import pandas as pd

# Re-define the students DataFrame as it was overwritten by a list in a previous cell
students = pd.DataFrame({
    "students":["John", "Mary", "Ali", "Grace",
                "James", "Faith", "Brian", "Lucy"],
    "Age":[20,21,22,20,23,21,22,20],
    "Gender":["Male", "Female", "Male", "Male",
              "Male", "Female", "Male", "Female"],
    "Math":[78,85,90,66,74,88,82,91],
    "Science":[80,79,95,70,88,90,76,90],
    "English":[75,88,92,72,81,86,79,90]
})

sns.barplot(data=students, x="Gender", y="Math")
plt.show()

# %%
#scater plot
sns.scatterplot(data=students, x="Math", y="Science", hue="Gender")
plt.show()

# %%
#Heatmap - Displays correlations between numerical variables
corr = students[["Math","Science","English"]].corr()
sns.heatmap(corr, annot=True, cmap="Blues")
plt.show()
